# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Đường dẫn ảnh
image_path = "input.jpg"  # đổi tên ảnh cho đúng

# Đọc ảnh
img = cv2.imread(image_path)

# Kiểm tra ảnh có đọc được không
print(img.shape)  # (height, width, channels)
# Out:
# (837, 843, 3)

# %%
# OpenCV dùng BGR → chuyển sang RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(842.5), np.float64(836.5), np.float64(-0.5))

# %%
# Resize về 300x300
resized = cv2.resize(img, (300, 300))

plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(842.5), np.float64(836.5), np.float64(-0.5))

# %%
blur = cv2.GaussianBlur(gray, (5, 5), 0)

plt.imshow(blur, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(842.5), np.float64(836.5), np.float64(-0.5))

# %%
_, binary = cv2.threshold(
    gray,
    0,
    255,
    cv2.THRESH_BINARY + cv2.THRESH_OTSU
)

plt.imshow(binary, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(842.5), np.float64(836.5), np.float64(-0.5))

# %%
titles = ["Original", "Gray", "Blur", "Binary"]
images = [
    img_rgb,
    gray,
    blur,
    binary
]

plt.figure(figsize=(10, 5))

for i in range(4):
    plt.subplot(1, 4, i+1)
    plt.title(titles[i])
    plt.imshow(images[i], cmap="gray")
    plt.axis("off")

plt.show()
